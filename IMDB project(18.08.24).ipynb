# %% [markdown]
# Questions
#
# 1. Load the data and perform basic data analysis.
#
# 2. Perform data cleaning, handle null values, checking data types of different variables.
#
# 3. How many movies are present in the data frame?
#
# 4. What is the total budget of all the movies combined?
#
# 5. Find the distribution of movies of different languages.
#
# 6. What are the top 5 most popular movies based on the popularity score?
#
# 7. What is the average runtime of all the movies in the dataframe?
#
# 8. How many movies were released after the year 2010?
#
# 9. List all movies with a budget greater than $50 million.
#
# 10. Filter the long English movies. ( runtime > 90)
#
# 11. Create a column as long_movies based on their runtime.
#
# 12. Find the distribution of movies for different years.
#
# 13. Sort the movies to analyze who has a low budget and high profit.
#
# 14. Is there a correlation between the budget and revenue of the movies?
#
# 15. How many movies belong to more than one genre?
#
# 16. Which movie has the highest revenue, and what is that revenue?
#
# 17. How many unique genres are present in the dataframe ?

# %% [markdown]
# ## **Import important tools**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
import datetime as dt

# %% [markdown]
# ## **IMDB Data reading and understanding**

# %%
df=pd.read_csv(r"C:\Users\DeLL\Downloads\imdb_data.csv")
df.T
# Out:
#                                                                     0     \
# id                                                                     1
# belongs_to_collection  [{'id': 313576, 'name': 'Hot Tub Time Machine ...
# budget                                                          14000000
# genres                                    [{'id': 35, 'name': 'Comedy'}]
# homepage                                                             NaN
# imdb_id                                                        tt2637294
# original_language                                                     en
# original_title                                    Hot Tub Time Machine 2
# overview               When Lou, who has become the "father of the In...
# popularity                                                      6.575393
# poster_path                             /tQtWuwvMf0hCc2QR2tkolwl7c3c.jpg
# production_companies   [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                     2/20/15
# runtime                                                             93.0
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                The Laws of Space and Time are About to be Vio...
# title                                             Hot Tub Time Machine 2
# Keywords               [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# cast                   [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# crew                   [{'credit_id': '59ac067c92514107af02c8c8', 'de...
# revenue                                                         12314651
#
#                                                                     1     \
# id                                                                     2
# belongs_to_collection  [{'id': 107674, 'name': 'The Princess Diaries ...
# budget                                                          40000000
# genres                 [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# homepage                                                             NaN
# imdb_id                                                        tt0368933
# original_language                                                     en
# original_title                  The Princess Diaries 2: Royal Engagement
# overview               Mia Thermopolis is now a college graduate and ...
# popularity                                                      8.248895
# poster_path                             /w9Z7A0GHEhIp7etpj0vyKOeU1Wx.jpg
# production_companies         [{'name': 'Walt Disney Pictures', 'id': 2}]
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                      8/6/04
# runtime                                                            113.0
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                It can take a lifetime to find true love; she'...
# title                           The Princess Diaries 2: Royal Engagement
# Keywords               [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# cast                   [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# crew                   [{'credit_id': '52fe43fe9251416c7502563d', 'de...
# revenue                                                         95149435
#
#                                                                     2     \
# id                                                                     3
# belongs_to_collection                                                NaN
# budget                                                           3300000
# genres                                     [{'id': 18, 'name': 'Drama'}]
# homepage                               http://sonyclassics.com/whiplash/
# imdb_id                                                        tt2582802
# original_language                                                     en
# original_title                                                  Whiplash
# overview               Under the direction of a ruthless instructor, ...
# popularity                                                      64.29999
# poster_path                             /lIv1QinFqz4dlp5U4lQ6HaiskOZ.jpg
# production_companies   [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                    10/10/14
# runtime                                                            105.0
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                  The road to greatness can take you to the edge.
# title                                                           Whiplash
# Keywords               [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# cast                   [{'cast_id': 5, 'character': 'Andrew Neimann',...
# crew                   [{'credit_id': '54d5356ec3a3683ba0000039', 'de...
# revenue                                                         13092000
#
#                                                                     3     \
# id                                                                     4
# belongs_to_collection                                                NaN
# budget                                                           1200000
# genres                 [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# homepage                                      http://kahaanithefilm.com/
# imdb_id                                                        tt1821480
# original_language                                                     hi
# original_title                                                   Kahaani
# overview               Vidya Bagchi (Vidya Balan) arrives in Kolkata ...
# popularity                                                      3.174936
# poster_path                             /aTXRaPrWSinhcmCrcfJK17urp3F.jpg
# production_companies                                                 NaN
# production_countries             [{'iso_3166_1': 'IN', 'name': 'India'}]
# release_date                                                      3/9/12
# runtime                                                            122.0
# spoken_languages       [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# status                                                          Released
# tagline                                                              NaN
# title                                                            Kahaani
# Keywords               [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# cast                   [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# crew                   [{'credit_id': '52fe48779251416c9108d6eb', 'de...
# revenue                                                         16000000
#
#                                                                     4     \
# id                                                                     5
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                 [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# homepage                                                             NaN
# imdb_id                                                        tt1380152
# original_language                                                     ko
# original_title                                                      마린보이
# overview               Marine Boy is the story of a former national s...
# popularity                                                       1.14807
# poster_path                             /m22s7zvkVFDU9ir56PiiqIEWFdT.jpg
# production_companies                                                 NaN
# production_countries       [{'iso_3166_1': 'KR', 'name': 'South Korea'}]
# release_date                                                      2/5/09
# runtime                                                            118.0
# spoken_languages                [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
# status                                                          Released
# tagline                                                              NaN
# title                                                         Marine Boy
# Keywords                                                             NaN
# cast                   [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# crew                   [{'credit_id': '52fe464b9251416c75073b43', 'de...
# revenue                                                          3923970
#
#                                                                     5     \
# id                                                                     6
# belongs_to_collection                                                NaN
# budget                                                           8000000
# genres                 [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# homepage                                                             NaN
# imdb_id                                                        tt0093743
# original_language                                                     en
# original_title                    Pinocchio and the Emperor of the Night
# overview               Pinocchio and his friends, a glow worm and a m...
# popularity                                                      0.743274
# poster_path                             /6IDqA1D2NBIVhzEEaMMRL28iBrq.jpg
# production_companies                                                 NaN
# production_countries                                                 NaN
# release_date                                                      8/6/87
# runtime                                                             83.0
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                                                              NaN
# title                             Pinocchio and the Emperor of the Night
# Keywords                                                             NaN
# cast                   [{'cast_id': 6, 'character': 'Pinocchio (voice...
# crew                   [{'credit_id': '52fe46f49251416c9106558b', 'de...
# revenue                                                          3261638
#
#                                                                     6     \
# id                                                                     7
# belongs_to_collection                                                NaN
# budget                                                          14000000
# genres                 [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# homepage                              http://www.thepossessionmovie.com/
# imdb_id                                                        tt0431021
# original_language                                                     en
# original_title                                            The Possession
# overview               A young girl buys an antique box at a yard sal...
# popularity                                                      7.286477
# poster_path                             /4QjzFuaZmB4btGnLwAgdp23BzIU.jpg
# production_companies   [{'name': 'Ghost House Pictures', 'id': 768}, ...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                     8/30/12
# runtime                                                             92.0
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                             Fear The Demon That Doesn't Fear God
# title                                                     The Possession
# Keywords                                                             NaN
# cast                   [{'cast_id': 23, 'character': 'Clyde', 'credit...
# crew                   [{'credit_id': '52fe4981c3a368484e12ee29', 'de...
# revenue                                                         85446075
#
#                                                                     7     \
# id                                                                     8
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                               [{'id': 99, 'name': 'Documentary'}]
# homepage                                                             NaN
# imdb_id                                                        tt0391024
# original_language                                                     en
# original_title                                              Control Room
# overview               A chronicle which provides a rare window into ...
# popularity                                                      1.949044
# poster_path                             /83BV8fGy5p9i8RwE9oj76tZ1Ikp.jpg
# production_companies                                                 NaN
# production_countries                                                 NaN
# release_date                                                     1/15/04
# runtime                                                             84.0
# spoken_languages       [{'iso_639_1': 'ar', 'name': 'العربية'}, {'iso...
# status                                                          Released
# tagline                            Different channels. Different truths.
# title                                                       Control Room
# Keywords               [{'id': 917, 'name': 'journalism'}, {'id': 163...
# cast                   [{'cast_id': 2, 'character': 'Himself', 'credi...
# crew                   [{'credit_id': '52fe47a69251416c750a0daf', 'de...
# revenue                                                          2586511
#
#                                                                     8     \
# id                                                                     9
# belongs_to_collection  [{'id': 256377, 'name': 'The Muppet Collection...
# budget                                                                 0
# genres                 [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# homepage                                                             NaN
# imdb_id                                                        tt0117110
# original_language                                                     en
# original_title                                    Muppet Treasure Island
# overview               After telling the story of Flint's last journe...
# popularity                                                      6.902423
# poster_path                             /5A8gKzOrF9Z7tSUX6xd5dEx4NXf.jpg
# production_companies   [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                     2/16/96
# runtime                                                            100.0
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                                      Set sail for Muppet mayhem!
# title                                             Muppet Treasure Island
# Keywords               [{'id': 2041, 'name': 'island'}, {'id': 4418, ...
# cast                   [{'cast_id': 1, 'character': 'Long John Silver...
# crew                   [{'credit_id': '52fe43c89251416c7501deb3', 'de...
# revenue                                                         34327391
#
#                                                                     9     ...  \
# id                                                                    10  ...
# belongs_to_collection                                                NaN  ...
# budget                                                           6000000  ...
# genres                 [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...  ...
# homepage                                                             NaN  ...
# imdb_id                                                        tt0310281  ...
# original_language                                                     en  ...
# original_title                                             A Mighty Wind  ...
# overview               In "A Mighty Wind", director Christopher Guest...  ...
# popularity                                                      4.672036  ...
# poster_path                             /xwD4EsPOGLuKP50Q1gwqAsyhAFB.jpg  ...
# production_companies   [{'name': 'Castle Rock Entertainment', 'id': 97}]  ...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# release_date                                                     4/16/03  ...
# runtime                                                             91.0  ...
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]  ...
# status                                                          Released  ...
# tagline                         Back together for the first time, again.  ...
# title                                                      A Mighty Wind  ...
# Keywords               [{'id': 11800, 'name': 'mockumentary'}, {'id':...  ...
# cast                   [{'cast_id': 24, 'character': 'Jonathan Steinb...  ...
# crew                   [{'credit_id': '52fe45609251416c750545b3', 'de...  ...
# revenue                                                         18750246  ...
#
#                                                                     2990  \
# id                                                                  2991
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                 [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# homepage                                                             NaN
# imdb_id                                                        tt0118663
# original_language                                                     en
# original_title                                                  B.A.P.S.
# overview               Can two clueless Georgia homegirls with big he...
# popularity                                                       1.56098
# poster_path                             /kdAJ4Q5uE1I8KhiJnoc3HvESynE.jpg
# production_companies   [{'name': 'New Line Cinema', 'id': 12}, {'name...
# production_countries                                                 NaN
# release_date                                                     3/28/97
# runtime                                                             90.0
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                              These Pretty Women... Are Clueless!
# title                                                           B.A.P.S.
# Keywords               [{'id': 1437, 'name': 'burglar'}, {'id': 1946,...
# cast                   [{'cast_id': 3, 'character': 'Nisi', 'credit_i...
# crew                   [{'credit_id': '52fe477b9251416c7509af57', 'de...
# revenue                                                          7240837
#
#                                                                     2991  \
# id                                                                  2992
# belongs_to_collection  [{'id': 107469, 'name': 'Save The Last Dance C...
# budget                                                          13000000
# genres                 [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# homepage                                                             NaN
# imdb_id                                                        tt0206275
# original_language                                                     en
# original_title                                       Save the Last Dance
# overview               A white midwestern girl moves to Chicago, wher...
# popularity                                                      4.794088
# poster_path                             /jnutEFGGdjJrLDxzJykI4ZviGe8.jpg
# production_companies   [{'name': 'MTV Films', 'id': 746}, {'name': 'C...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                     1/12/01
# runtime                                                            112.0
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                      The Only Person You Need To Be Is Yourself.
# title                                                Save the Last Dance
# Keywords               [{'id': 4118, 'name': 'ballet dancer'}, {'id':...
# cast                   [{'cast_id': 18, 'character': 'Sara Johnson', ...
# crew                   [{'credit_id': '52fe4533c3a36847f80c1c6b', 'de...
# revenue                                                         91038276
#
#                                                                     2992  \
# id                                                                  2993
# belongs_to_collection                                                NaN
# budget                                                           1135654
# genres                 [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# homepage                                                             NaN
# imdb_id                                                        tt0015400
# original_language                                                     en
# original_title                                       The Thief of Bagdad
# overview               A recalcitrant thief vies with a duplicitous M...
# popularity                                                      3.878515
# poster_path                             /a6IzXkwZRDimfn8HATzP6Pi6Ois.jpg
# production_companies   [{'name': 'Douglas Fairbanks Pictures', 'id': ...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                     3/18/24
# runtime                                                            149.0
# spoken_languages            [{'iso_639_1': 'xx', 'name': 'No Language'}]
# status                                                          Released
# tagline                                       "Happiness Must Be Earned"
# title                                                The Thief of Bagdad
# Keywords               [{'id': 255, 'name': 'male nudity'}, {'id': 14...
# cast                   [{'cast_id': 3, 'character': 'The Thief of Bag...
# crew                   [{'credit_id': '52fe45bec3a368484e06c70b', 'de...
# revenue                                                          1213880
#
#                                                                     2993  \
# id                                                                  2994
# belongs_to_collection                                                NaN
# budget                                                          60000000
# genres                 [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# homepage                            http://www.theterminal-themovie.com/
# imdb_id                                                        tt0362227
# original_language                                                     en
# original_title                                              The Terminal
# overview               Viktor Navorski is a man without a country; hi...
# popularity                                                     14.092373
# poster_path                             /f4Dup6awDfDqAHKgWqNJ2HFw1qN.jpg
# production_companies   [{'name': 'DreamWorks SKG', 'id': 27}, {'name'...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                     6/17/04
# runtime                                                            128.0
# spoken_languages       [{'iso_639_1': 'bg', 'name': 'български език'}...
# status                                                          Released
# tagline                                                 Life is waiting.
# title                                                       The Terminal
# Keywords               [{'id': 242, 'name': 'new york'}, {'id': 822, ...
# cast                   [{'cast_id': 4, 'character': 'Viktor Navorski'...
# crew                   [{'credit_id': '52fe4259c3a36847f8017699', 'de...
# revenue                                                        219417255
#
#                                                                     2994  \
# id                                                                  2995
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                                     [{'id': 18, 'name': 'Drama'}]
# homepage                                                             NaN
# imdb_id                                                        tt0105327
# original_language                                                     en
# original_title                                               School Ties
# overview               When David Greene receives a football scholars...
# popularity                                                      7.438381
# poster_path                             /poV3j71mcmQkmjezc2H35xJsAhD.jpg
# production_companies           [{'name': 'Paramount Pictures', 'id': 4}]
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                     9/18/92
# runtime                                                            106.0
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                Just because you’re accepted doesn’t mean you ...
# title                                                        School Ties
# Keywords               [{'id': 6075, 'name': 'sport'}, {'id': 10144, ...
# cast                   [{'cast_id': 2, 'character': 'David Greene', '...
# crew                   [{'credit_id': '5637777ac3a3681b4d01f9f5', 'de...
# revenue                                                         14715067
#
#                                                                     2995  \
# id                                                                  2996
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                 [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# homepage                                                             NaN
# imdb_id                                                        tt0109403
# original_language                                                     en
# original_title                                                   Chasers
# overview               Military men Rock Reilly and Eddie Devane are ...
# popularity                                                       9.85327
# poster_path                             /j8Q7pQ27hvH54wpxJzIuQgQCdro.jpg
# production_companies   [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                     4/22/94
# runtime                                                            102.0
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                It was supposed to be a routine prisoner trans...
# title                                                            Chasers
# Keywords               [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# cast                   [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# crew                   [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...
# revenue                                                          1596687
#
#                                                                     2996  \
# id                                                                  2997
# belongs_to_collection                                                NaN
# budget                                                                 0
# genres                 [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# homepage                                                             NaN
# imdb_id                                                        tt2364975
# original_language                                                     sv
# original_title                                               Vi är bäst!
# overview               Three girls in 1980s Stockholm decide to form ...
# popularity                                                      3.727996
# poster_path                             /sS01LSy6KDrCZAhtkO18UdnWFT1.jpg
# production_companies   [{'name': 'Memfis Film', 'id': 321}, {'name': ...
# production_countries   [{'iso_3166_1': 'DK', 'name': 'Denmark'}, {'is...
# release_date                                                     3/28/13
# runtime                                                            102.0
# spoken_languages                [{'iso_639_1': 'sv', 'name': 'svenska'}]
# status                                                          Released
# tagline                                                              NaN
# title                                                   We Are the Best!
# Keywords               [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...
# cast                   [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# crew                   [{'credit_id': '5716b72ac3a3686678012c84', 'de...
# revenue                                                           180590
#
#                                                                     2997  \
# id                                                                  2998
# belongs_to_collection                                                NaN
# budget                                                          65000000
# genres                 [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# homepage                                                             NaN
# imdb_id                                                        tt0116908
# original_language                                                     en
# original_title                                   The Long Kiss Goodnight
# overview               Samantha Caine, suburban homemaker, is the ide...
# popularity                                                     14.482345
# poster_path                             /4MENR8x6mYqnZvp2hGjSaPJz64J.jpg
# production_companies   [{'name': 'New Line Cinema', 'id': 12}, {'name...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                    10/11/96
# runtime                                                            120.0
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                             What's forgotten is not always gone.
# title                                            The Long Kiss Goodnight
# Keywords               [{'id': 441, 'name': 'assassination'}, {'id': ...
# cast                   [{'cast_id': 10, 'character': 'Samantha Caine ...
# crew                   [{'credit_id': '52fe443a9251416c7502d579', 'de...
# revenue                                                         89456761
#
#                                                                     2998  \
# id                                                                  2999
# belongs_to_collection                                                NaN
# budget                                                          42000000
# genres                 [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# homepage                                  http://www.alongcamepolly.com/
# imdb_id                                                        tt0343135
# original_language                                                     en
# original_title                                          Along Came Polly
# overview               Reuben Feffer is a guy who's spent his entire ...
# popularity                                                     15.725542
# poster_path                             /nIY4kvJTTnxoBR0wycrXng5MOYs.jpg
# production_companies   [{'name': 'Jersey Films', 'id': 216}, {'name':...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                     1/16/04
# runtime                                                             90.0
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                For the most cautious man on Earth, life is ab...
# title                                                   Along Came Polly
# Keywords               [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# cast                   [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# crew                   [{'credit_id': '556f817b9251410866000a63', 'de...
# revenue                                                        171963386
#
#                                                                     2999
# id                                                                  3000
# belongs_to_collection                                                NaN
# budget                                                          35000000
# genres                 [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# homepage                                http://www.abductionthefilm.com/
# imdb_id                                                        tt1600195
# original_language                                                     en
# original_title                                                 Abduction
# overview               A young man sets out to uncover the truth abou...
# popularity                                                     10.512109
# poster_path                             /cUT6NQP5LAJpmUoStGtXmvNt4zA.jpg
# production_companies   [{'name': 'Lions Gate Films', 'id': 35}, {'nam...
# production_countries   [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                                     9/22/11
# runtime                                                            106.0
# spoken_languages                [{'iso_639_1': 'en', 'name': 'English'}]
# status                                                          Released
# tagline                        They stole his life. He's taking it back.
# title                                                          Abduction
# Keywords               [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
# cast                   [{'cast_id': 2, 'character': 'Nathan Harper', ...
# crew                   [{'credit_id': '5391990d0e0a260fb5001629', 'de...
# revenue                                                         82087155
#
# [23 rows x 3000 columns]

# %% [markdown]
# #### **2.Perform data cleaning, handle null values, checking data types of different variables.**

# %%
## Information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
#  14  runtime                2998 non-null   float64
#  15  spoken_languages       2980 non-null   object
#  16  status                 3000 non-null   object
#  17  tagline                2403 non-null   object
#  18  title                  3000 non-null   object
#  19  Keywords               2724 non-null   object
#  20  cast                   2987 non-null   object
#  21  crew                   2984 non-null   object
#  22  revenue                3000 non-null   int64
# dtypes: float64(2), int64(3), object(18)
# memory usage: 539.2+ KB

# %%
## For null and missing value
df.isnull().sum()
# Out:
# id                          0
# belongs_to_collection    2396
# budget                      0
# genres                      7
# homepage                 2054
# imdb_id                     0
# original_language           0
# original_title              0
# overview                    8
# popularity                  0
# poster_path                 1
# production_companies      156
# production_countries       55
# release_date                0
# runtime                     2
# spoken_languages           20
# status                      0
# tagline                   597
# title                       0
# Keywords                  276
# cast                       13
# crew                       16
# revenue                     0
# dtype: int64

# %%
df.describe().T
# Out:
#              count          mean           std       min           25%  \
# id          3000.0  1.500500e+03  8.661697e+02  1.000000  7.507500e+02
# budget      3000.0  2.253133e+07  3.702609e+07  0.000000  0.000000e+00
# popularity  3000.0  8.463274e+00  1.210400e+01  0.000001  4.018053e+00
# runtime     2998.0  1.078566e+02  2.208643e+01  0.000000  9.400000e+01
# revenue     3000.0  6.672585e+07  1.375323e+08  1.000000  2.379808e+06
#
#                      50%           75%           max
# id          1.500500e+03  2.250250e+03  3.000000e+03
# budget      8.000000e+06  2.900000e+07  3.800000e+08
# popularity  7.374861e+00  1.089098e+01  2.943370e+02
# runtime     1.040000e+02  1.180000e+02  3.380000e+02
# revenue     1.680707e+07  6.891920e+07  1.519558e+09

# %%
#columns
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
df = df[['id', 'budget', 'genres', 'original_language', 'original_title',
       'popularity', 'production_companies',
       'production_countries', 'release_date', 'runtime',
       'status', 'cast', 'crew', 'revenue']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    3000 non-null   int64
#  1   budget                3000 non-null   int64
#  2   genres                2993 non-null   object
#  3   original_language     3000 non-null   object
#  4   original_title        3000 non-null   object
#  5   popularity            3000 non-null   float64
#  6   production_companies  2844 non-null   object
#  7   production_countries  2945 non-null   object
#  8   release_date          3000 non-null   object
#  9   runtime               2998 non-null   float64
#  10  status                3000 non-null   object
#  11  cast                  2987 non-null   object
#  12  crew                  2984 non-null   object
#  13  revenue               3000 non-null   int64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 328.3+ KB

# %%
df.describe().T
# Out:
#              count          mean           std       min           25%  \
# id          3000.0  1.500500e+03  8.661697e+02  1.000000  7.507500e+02
# budget      3000.0  2.253133e+07  3.702609e+07  0.000000  0.000000e+00
# popularity  3000.0  8.463274e+00  1.210400e+01  0.000001  4.018053e+00
# runtime     2998.0  1.078566e+02  2.208643e+01  0.000000  9.400000e+01
# revenue     3000.0  6.672585e+07  1.375323e+08  1.000000  2.379808e+06
#
#                      50%           75%           max
# id          1.500500e+03  2.250250e+03  3.000000e+03
# budget      8.000000e+06  2.900000e+07  3.800000e+08
# popularity  7.374861e+00  1.089098e+01  2.943370e+02
# runtime     1.040000e+02  1.180000e+02  3.380000e+02
# revenue     1.680707e+07  6.891920e+07  1.519558e+09

# %% [markdown]
# ### **3). How many movies are present in the data frame?**

# %%
df.shape[0]
# Out:
# 3000

# %% [markdown]
# ### **4). What is the total budget of all the movies combined?**

# %%
df['budget'].sum()
# Out:
# 67594002330

# %% [markdown]
# ### **5). Find the distribution of movies of different languages.**

# %%
df.groupby('original_language')["id"].count()
#df['original_language'].value_counts()
# Out:
# original_language
# ar       1
# bn       1
# cn      20
# cs       1
# da       5
# de      18
# el       1
# en    2575
# es      43
# fa       5
# fi       2
# fr      78
# he       1
# hi      42
# hu       3
# id       1
# it      24
# ja      37
# ko      20
# ml       2
# mr       1
# nb       1
# nl       6
# no       2
# pl       2
# pt       6
# ro       4
# ru      47
# sr       1
# sv       8
# ta      16
# te       2
# tr       3
# ur       1
# vi       1
# zh      19
# Name: id, dtype: int64

# %% [markdown]
# ### **6). What are the top 5 most popular movies based on the popularity score?**

# %%
df.sort_values('popularity', ascending=False).head(5)
#df.sort_values(by = 'popularity', ascending=False).head(5)
# Out:
#         id     budget                                             genres  \
# 518    519  149000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 684    685  160000000  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...
# 1695  1696   34000000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 2326  2327   58000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2126  2127  200000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
#
#      original_language                  original_title  popularity  \
# 518                 en                    Wonder Woman  294.337037
# 684                 en            Beauty and the Beast  287.253654
# 1695                en                     Baby Driver  228.032744
# 2326                en                        Deadpool  187.860492
# 2126                en  Guardians of the Galaxy Vol. 2  185.330992
#
#                                    production_companies  \
# 518   [{'name': 'Dune Entertainment', 'id': 444}, {'...
# 684   [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
# 1695  [{'name': 'Big Talk Productions', 'id': 443}, ...
# 2326  [{'name': 'Twentieth Century Fox Film Corporat...
# 2126  [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
#
#                                    production_countries release_date  runtime  \
# 518   [{'iso_3166_1': 'US', 'name': 'United States o...      5/30/17    141.0
# 684   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...      3/16/17    129.0
# 1695  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...      6/28/17    113.0
# 2326  [{'iso_3166_1': 'US', 'name': 'United States o...       2/9/16    108.0
# 2126  [{'iso_3166_1': 'US', 'name': 'United States o...      4/19/17    137.0
#
#         status                                               cast  \
# 518   Released                                                NaN
# 684   Released  [{'cast_id': 174, 'character': 'Belle', 'credi...
# 1695  Released  [{'cast_id': 9, 'character': 'Baby', 'credit_i...
# 2326  Released  [{'cast_id': 99, 'character': 'Wade Wilson / D...
# 2126  Released  [{'cast_id': 3, 'character': 'Peter Quill / St...
#
#                                                    crew     revenue
# 518                                                 NaN   820580447
# 684   [{'credit_id': '551879bec3a3681f840004eb', 'de...  1262886337
# 1695  [{'credit_id': '55c58c009251417a21000e5d', 'de...   224511319
# 2326  [{'credit_id': '57e564fac3a3681beb0000cc', 'de...   783112979
# 2126  [{'credit_id': '59171547925141583c0315a6', 'de...   863416141

# %% [markdown]
# ### **7). What is the average runtime of all the movies in the dataframe?**

# %%
df['runtime'].mean()
# Out:
# 107.85657104736491

# %%
import warnings
warnings.filterwarnings("ignore")
import datetime as dt
df['release_date']=pd.to_datetime(df['release_date'])
df['year'] = df['release_date'].dt.year
df.head(1)
# Out:
#    id    budget                          genres original_language  \
# 0   1  14000000  [{'id': 35, 'name': 'Comedy'}]                en
#
#            original_title  popularity  \
# 0  Hot Tub Time Machine 2    6.575393
#
#                                 production_companies  \
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
#
#                                 production_countries release_date  runtime  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2015-02-20     93.0
#
#      status                                               cast  \
# 0  Released  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
#
#                                                 crew   revenue  year
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651  2015

# %% [markdown]
# ### **8). How many movies were released after the year 2010?**

# %%
filtered_df = df[df['year'] > 2010]
filtered_df.shape[0]
# Out:
# 991

# %% [markdown]
# ### **9). List all movies with a budget greater than $50 million.**

# %%
high_budget_movie_df = df[df['budget'] > 50000000]
high_budget_movie_df.shape
# Out:
# (394, 15)

# %% [markdown]
# ### **10). Filter the long English movies. ( runtime > 90)**

# %%
long_eng_movie_df  = df[ (df['runtime'] > 90) & (df['original_language'] == 'en') ]
long_eng_movie_df.shape
# Out:
# (2135, 15)

# %% [markdown]
# ### **11). Create a column as long_movies based on their runtime.**

# %%
threshold_runtime =  df['runtime'].median()
threshold_runtime
# Out:
# 104.0

# %%
# .astype(int) means --> replcing the string value true or false= 0 or 1
df['long_movies'] = (df['runtime'] > threshold_runtime).astype(int)
df.head(2)
# Out:
#    id    budget                                             genres  \
# 0   1  14000000                     [{'id': 35, 'name': 'Comedy'}]
# 1   2  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
#
#   original_language                            original_title  popularity  \
# 0                en                    Hot Tub Time Machine 2    6.575393
# 1                en  The Princess Diaries 2: Royal Engagement    8.248895
#
#                                 production_companies  \
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1        [{'name': 'Walt Disney Pictures', 'id': 2}]
#
#                                 production_countries release_date  runtime  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...   2015-02-20     93.0
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2004-08-06    113.0
#
#      status                                               cast  \
# 0  Released  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  Released  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
#
#                                                 crew   revenue  year  \
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651  2015
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435  2004
#
#    long_movies
# 0            0
# 1            1

# %% [markdown]
# ### **12). Find the frequency distribution of movies for different years.**

# %%
df.groupby('year')['id'].count()
#df['year'].value_counts()
# Out:
# year
# 1974     5
# 1975     8
# 1976     7
# 1977    11
# 1978    14
#         ..
# 2069     6
# 2070     8
# 2071     8
# 2072     8
# 2073     9
# Name: id, Length: 90, dtype: int64

# %% [markdown]
# ### **13). Sort the movies to analyze who has a low budget and high profit.**

# %%
df['profit'] = df['revenue'] - df['budget']

# %%
df.sort_values(by = ['budget','profit'],ascending=[True, False]).head(3)
# Out:
#         id  budget                                             genres  \
# 117    118       0  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1569  1570       0  [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 818    819       0  [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
#
#      original_language                          original_title  popularity  \
# 117                 en                               Wild Hogs   11.356011
# 1569                en                     Crocodile Dundee II    8.948565
# 818                 en  Alvin and the Chipmunks: The Road Chip   14.307672
#
#                                    production_companies  \
# 117   [{'name': 'Wild Hogs Productions', 'id': 6354}...
# 1569          [{'name': 'Paramount Pictures', 'id': 4}]
# 818   [{'name': 'Regency Enterprises', 'id': 508}, {...
#
#                                    production_countries release_date  runtime  \
# 117   [{'iso_3166_1': 'US', 'name': 'United States o...   2007-03-02    100.0
# 1569  [{'iso_3166_1': 'AU', 'name': 'Australia'}, {'...   1988-05-19    110.0
# 818   [{'iso_3166_1': 'US', 'name': 'United States o...   2015-12-17     92.0
#
#         status                                               cast  \
# 117   Released  [{'cast_id': 1, 'character': 'Doug Madsen', 'c...
# 1569  Released  [{'cast_id': 1, 'character': "Michael J. 'Croc...
# 818   Released  [{'cast_id': 16, 'character': 'Dave', 'credit_...
#
#                                                    crew    revenue  year  \
# 117   [{'credit_id': '52fe440e9251416c750276bb', 'de...  253625427  2007
# 1569  [{'credit_id': '52fe44f2c3a36847f80b36c7', 'de...  239606210  1988
# 818   [{'credit_id': '547f79b7c3a3683d8e0004fe', 'de...  233755553  2015
#
#       long_movies     profit
# 117             0  253625427
# 1569            1  239606210
# 818             0  233755553

# %% [markdown]
# ### **14). Is there a correlation between the budget and revenue of the movies?**

# %%
df[['budget','revenue']].corr()
# Out:
#            budget   revenue
# budget   1.000000  0.752965
# revenue  0.752965  1.000000

# %% [markdown]
# - There are moderate correlation between budget and revenue variables.

# %% [markdown]
# ### **15). How many movies belong to more than one genre?**

# %%
print(df['genres'][0])
print(df['genres'][1])
# Out:
# [{'id': 35, 'name': 'Comedy'}]
# [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}, {'id': 10749, 'name': 'Romance'}]

# %%
name = "Hero vired"
len(name)
# Out:
# 10

# %%
def convert_to_list(str):
    return eval(str)

# %%
df1['genres'] = df1['genres'].apply(convert_to_list)
df1.shape
# Out:
# (2993, 17)

# %%
df1 = df[~df['genres'].isna()]

# %%
#to tackle the null values 
df1.loc[~df1['genres'].isna(),'genres'] = df1.loc[~df1['genres'].isna(),'genres'].apply(convert_to_list)

# %%
df1['genres'][1]
# Out:
# [{'id': 35, 'name': 'Comedy'},
#  {'id': 18, 'name': 'Drama'},
#  {'id': 10751, 'name': 'Family'},
#  {'id': 10749, 'name': 'Romance'}]

# %%
len(df1['genres'][0])
# Out:
# 1

# %%
len(df1['genres'][1])
# Out:
# 4

# %%
res_mov = df1[df1['genres'].apply (lambda x : len(x)) > 1]
res_mov.head()
# Out:
#    id    budget                                             genres  \
# 1   2  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 3   4   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4   5         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 5   6   8000000  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6   7  14000000  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#   original_language                            original_title  popularity  \
# 1                en  The Princess Diaries 2: Royal Engagement    8.248895
# 3                hi                                   Kahaani    3.174936
# 4                ko                                      마린보이    1.148070
# 5                en    Pinocchio and the Emperor of the Night    0.743274
# 6                en                            The Possession    7.286477
#
#                                 production_companies  \
# 1        [{'name': 'Walt Disney Pictures', 'id': 2}]
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  [{'name': 'Ghost House Pictures', 'id': 768}, ...
#
#                                 production_countries release_date  runtime  \
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...   2004-08-06    113.0
# 3            [{'iso_3166_1': 'IN', 'name': 'India'}]   2012-03-09    122.0
# 4      [{'iso_3166_1': 'KR', 'name': 'South Korea'}]   2009-02-05    118.0
# 5                                                NaN   1987-08-06     83.0
# 6  [{'iso_3166_1': 'US', 'name': 'United States o...   2012-08-30     92.0
#
#      status                                               cast  \
# 1  Released  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 3  Released  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  Released  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# 5  Released  [{'cast_id': 6, 'character': 'Pinocchio (voice...
# 6  Released  [{'cast_id': 23, 'character': 'Clyde', 'credit...
#
#                                                 crew   revenue  year  \
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435  2004
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000  2012
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970  2009
# 5  [{'credit_id': '52fe46f49251416c9106558b', 'de...   3261638  1987
# 6  [{'credit_id': '52fe4981c3a368484e12ee29', 'de...  85446075  2012
#
#    long_movies    profit
# 1            1  55149435
# 3            1  14800000
# 4            1   3923970
# 5            0  -4738362
# 6            0  71446075

# %% [markdown]
# ### **16). Which movie has the highest revenue, and what is that revenue?**

# %%
df.loc[df['revenue'].idxmax()]
# Out:
# id                                                                   1127
# budget                                                          220000000
# genres                  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# original_language                                                      en
# original_title                                               The Avengers
# popularity                                                      89.887648
# production_companies    [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# production_countries    [{'iso_3166_1': 'US', 'name': 'United States o...
# release_date                                          2012-04-25 00:00:00
# runtime                                                             143.0
# status                                                           Released
# cast                    [{'cast_id': 46, 'character': 'Tony Stark / Ir...
# crew                    [{'credit_id': '52fe4495c3a368484e02b1cf', 'de...
# revenue                                                        1519557910
# year                                                                 2012
# long_movies                                                             1
# profit                                                         1299557910
# Name: 1126, dtype: object

# %% [markdown]
# ### **17). How many unique genres are present in the dataframe ?**

# %%
# Get the unique genres
(df['genres'].unique().shape[0])
# Out:
# 873
